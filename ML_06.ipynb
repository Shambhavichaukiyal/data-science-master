# %% [markdown]
# Q1. What is the difference between Ordinal Encoding and Label Encoding? Provide an example of when you
# might choose one over the other.
# Q2. Explain how Target Guided Ordinal Encoding works and provide an example of when you might use it in
# a machine learning project.
# Q3. Define covariance and explain why it is important in statistical analysis. How is covariance calculated?
# Q4. For a dataset with the following categorical variables: Color (red, green, blue), Size (small, medium,
# large), and Material (wood, metal, plastic), perform label encoding using Python's scikit-learn library.
# Show your code and explain the output.
# Q5. Calculate the covariance matrix for the following variables in a dataset: Age, Income, and Education
# level. Interpret the results.
# Q6. You are working on a machine learning project with a dataset containing several categorical
# variables, including "Gender" (Male/Female), "Education Level" (High School/Bachelor's/Master's/PhD),
# and "Employment Status" (Unemployed/Part-Time/Full-Time). Which encoding method would you use for
# each variable, and why?
# Q7. You are analyzing a dataset with two continuous variables, "Temperature" and "Humidity", and two
# categorical variables, "Weather Condition" (Sunny/Cloudy/Rainy) and "Wind Direction" (North/South/
# East/West). Calculate the covariance between each pair of variables and interpret the results.

# %% [markdown]
# Ordinal encoding in which we can rank the categorical data.
# Labe encoding in which we give unique integer to the categorical data.

# %%
#For Ordinal -size
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd
df=pd.DataFrame({'size':['large','medium','small','large','small','medium']})
oe=OrdinalEncoder(categories=[['large','medium','small']])
m=oe.fit_transform(df[['size']])

# %%
m
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [1.]])

# %% [markdown]
# Q2. Explain how Target Guided Ordinal Encoding works and provide an example of when you might use it in
# a machine learning project.
# Target Guided Ordinal encoding is used when categorical data highly correlates to the target column.
# If I am given city and price of something in that particular city.

# %%
import pandas as pd
df=pd.DataFrame({'city':['delhi','dehradun','jaipur','hyderabad','pune','mumbai','pune','mumbai','jaipur'],
                 'price':[180,200,3939,3903,333,2334,567,7,8]})
df['new_price'] = df.groupby('city')['price'].transform('mean')
df
# Out:
#         city  price  new_price
# 0      delhi    180      180.0
# 1   dehradun    200      200.0
# 2     jaipur   3939     1973.5
# 3  hyderabad   3903     3903.0
# 4       pune    333      450.0
# 5     mumbai   2334     1170.5
# 6       pune    567      450.0
# 7     mumbai      7     1170.5
# 8     jaipur      8     1973.5

# %% [markdown]
# Define covariance and explain why it is important in statistical analysis. How is covariance calculated?
# Covariance tells us how 2 features are realted to each other .Covariance is calculated by summation of X i feature substract X mean multiply Y i feature substract Y mean divide by varinace of X and Y.

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Create DataFrame
df = pd.DataFrame({
    'Color': ['red', 'blue', 'green'],
    'Size': ['small', 'medium', 'large'],
    'Material': ['wood', 'metal', 'plastic']
})

# Initialize LabelEncoder
le = LabelEncoder()

# Apply label encoding column-wise
df['Color_encoded'] = le.fit_transform(df['Color'])
df['Size_encoded'] = le.fit_transform(df['Size'])
df['Material_encoded'] = le.fit_transform(df['Material'])

print(df)
# Out:
#    Color    Size Material  Color_encoded  Size_encoded  Material_encoded
# 0    red   small     wood              2             2                 2
# 1   blue  medium    metal              0             1                 0
# 2  green   large  plastic              1             0                 1

# %%
import pandas as pd

# Sample dataset
data = {
    'Age': [25, 30, 22, 35, 28],
    'Income': [50000, 60000, 45000, 80000, 52000],
    'Education_Level': [12, 16, 10, 18, 14]  # in years of schooling
}

df = pd.DataFrame(data)
s=df.cov()

# %% [markdown]
# Q6. You are working on a machine learning project with a dataset containing several categorical
# variables, including "Gender" (Male/Female), "Education Level" (High School/Bachelor's/Master's/PhD),
# and "Employment Status" (Unemployed/Part-Time/Full-Time). Which encoding method would you use for
# each variable, and why?
# Gender-binary just 2 values
# Education Level-Ordinal as rank is present
# Employmentstatus-OneHotEncoder

# %% [markdown]
# You are analyzing a dataset with two continuous variables, "Temperature" and "Humidity", and two
# categorical variables, "Weather Condition" (Sunny/Cloudy/Rainy) and "Wind Direction" (North/South/
# East/West). Calculate the covariance between each pair of variables and interpret the results.

# %%
import pandas as pd

# Sample data
data = {
    'Temperature': [30, 25, 28, 22, 35],
    'Humidity': [70, 65, 60, 80, 50],
    'Weather_Condition': ['Sunny', 'Cloudy', 'Rainy', 'Sunny', 'Cloudy'],
    'Wind_Direction': ['North', 'South', 'East', 'West', 'North']
}

df = pd.DataFrame(data)
df.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 12
#       4 data = {
#       5     'Temperature': [30, 25, 28, 22, 35],
#       6     'Humidity': [70, 65, 60, 80, 50],
#       7     'Weather_Condition': ['Sunny', 'Cloudy', 'Rainy', 'Sunny', 'Cloudy'],
#       8     'Wind_Direction': ['North', 'South', 'East', 'West', 'North']
#       9 }
#      11 df = pd.DataFrame(data)
# ---> 12 df.cov()
#
# File c:\Users\91897\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11211, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11209 cols = data.columns
#   11210 idx = cols.copy()
# > 11211 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11213 if notna(mat).all():
#   11214     if min_periods is not None and min_periods > len(mat):
#
# ...

# %%
import pandas as pd
from sklearn .preprocessing import LabelEncoder

# Sample data
data = {
    'Temperature': [30, 25, 28, 22, 35],
    'Humidity': [70, 65, 60, 80, 50],
    'Weather_Condition': ['Sunny', 'Cloudy', 'Rainy', 'Sunny', 'Cloudy'],
    'Wind_Direction': ['North', 'South', 'East', 'West', 'North']
}

df = pd.DataFrame(data)
le=LabelEncoder()

df['new_WC']=le.fit_transform(df[['Weather_Condition']])
df['new_WD']=le.fit_transform(df[['Wind_Direction']])

cov_matrix = df[['Temperature', 'Humidity', 'new_WC', 'new_WD']].cov()
print(cov_matrix)
# Out:
#              Temperature  Humidity  new_WC  new_WD
# Temperature        24.50    -46.25   -2.00   -3.75
# Humidity          -46.25    125.00    8.75    8.75
# new_WC             -2.00      8.75    1.00    0.25
# new_WD             -3.75      8.75    0.25    1.30
# c:\Users\91897\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\91897\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

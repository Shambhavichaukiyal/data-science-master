# %% [markdown]
# z-test is used when sampe size is greater than 30 and standard deviation is given there is no degree of freedom while t test is for sample size les than 30 and standard deviation can be given or not and there is degree of freedom.

# %% [markdown]
# One-tailed Test
# A one-tailed test checks for an effect in only one direction.If we want to find greater than or less than
# Two_tailed test
# A one-tailed test checks for an effect in both direction.

# %% [markdown]
# #Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.
#
# Type 1 -Type I error occurs when the null hypothesis is TRUE, but we reject it.
# Type 2-Type II error occurs when the null hypothesis is FALSE, but we fail to reject it.

# %% [markdown]
# Bayes’s theorem is used to find the conditional probability of an event based on prior knowledge or related information.
# ![image.png](attachment:image.png)

# %% [markdown]
# A confidence interval is a range of values within which the true population parameter (mean or proportion) is expected to lie with a certain level of confidence (such as 95% or 99%).
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Sample Problem
#
# A disease affects 5% of the population.
# A medical test:
#
# Correctly identifies diseased people 90% of the time
#
# Incorrectly identifies healthy people as diseased 10% of the time
#
# If a person tests positive, what is the probability that they actually have the disease?
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# sample mean=50
# std=5
# confidence level=95
# alpha=0.05
# n=100
# z0.025​=1.96
# SE=0.5
# ME=1.96*0.5=0.98
# 50+-(0.98)

# %% [markdown]
# Margin of Error (ME)=Critical value×Standard Error (SE)

# %% [markdown]
# value=75
# mean=70
#  std=5
#  z=1

# %% [markdown]
# null hypothesis-
# mean=0
#
# alternate hypothesis-
# mean> 0
#
# n=50
# std=2.5
# lose weight mean=6
# confidence level=95
# t=17
#
# df=n-1 =49
#
# tcritical=1.67
#
# 17>1.67
# rejec the null hypothesis

# %% [markdown]
# n=500
# p=0.65
#
# z0.025=1.96
# SE=0.0213
# ME=0.0417
#
# CI=0.65±0.0417

# %% [markdown]
# null hypothesis
# mean1=mean2
#
# alternate hypothesis
# mean1 not equal to mean2
#
# ![image.png](attachment:image.png)
#
# t=2.10
#
# df-n1+n2-2=58
# tcritivcal=2.66
# fail to reject null hypothesis

# %% [markdown]
# std=8
# mean=65
# sample n=50
# Confidence level: 90%
# z0.05​=1.645
#
# SE=1.13
# ME=1.86

# %% [markdown]
# The average reaction time without caffeine is 0.30 seconds
#
# Population standard deviation is unknown
#
# Sample size is small (n=30)
# null hypothesis
# mean=0.30
#
# alternate hypothesis
# mean not equal to 0.30
#
# α=0.10
#
# t=-5.48
#
# df=29
#
# tcritical​≈±1.699
#
# Reject the null hypothesis

# %% [markdown]
# Web Scraping is the process of automatically extracting data from websites.Web scraping is used to collect large amounts of data efficiently and quickly when the data is not available through official APIs.
# E-commerce and Price Comparison
# market comparison
# Finance and Stock Market Analysis

# %% [markdown]
# Using Regular Expressions (Regex)
# HTML Parsing
# Manual Web Scraping

# %% [markdown]
# Beautiful Soup is a Python library used for parsing HTML and XML documents. It converts the raw webpage source code into a structured, searchable format (called a parse tree), making it easy to extract specific data from web pages.
# It is used in HTML Parsing

# %% [markdown]
# Connects Frontend and backend
# Make it easy to understand

# %% [markdown]
# AWS Elastic Beanstalk
#
# AWS Elastic Beanstalk is a Platform as a Service (PaaS) that makes it easy to deploy, manage, and scale web applications.
#
# AWS CodePipeline
#
# AWS CodePipeline is a Continuous Integration and Continuous Deployment (CI/CD) service.

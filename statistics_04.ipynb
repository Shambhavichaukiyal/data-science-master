# %% [markdown]
# pmf-probability mass function it is applied on discrete random data.ex-Consider tossing a fair coin.
# pdf-probabibilty denstity function it is applied on continuous random data.ex-Consider the height of students (continuous data).

# %% [markdown]
# The Cumulative Distribution Function (CDF) of a random variable X is defined as the probability that X takes a value less than or equal to a given value x.Probabiity of getting number less than 4 in a dice roll.
# It is used to find probability of less than or equal to.

# %% [markdown]
# The normal distribution is commonly used to model data that are continuous, symmetric, and cluster around a mean
# Heights and weights of people in a population
#
# Marks or test scores of a large group of students
#
# Measurement errors in scientific experiments
#
# IQ scores in psychology

# %% [markdown]
# CLT
# Foundation of statistical analysis
# Real-Life Examples of Normal Distribution
#
# Heights and weights of people in a population
#
# Marks or scores of students in large examinations
#
# IQ scores and psychological test results
#
# Measurement errors in experiments
#
# Blood pressure and body temperature
#
# Manufacturing measurements (length, weight, diameter of products)

# %% [markdown]
#  Bernaulli Distribution when there is 2 output true or false.Tossing of coin P(H)=0.5 and P(T)=0.5.mean=p,Variance=pq=p(1−p),median=0 or 1
#  Binomial is n number of trail for bernaulli distribution.Tossing of coin n types.Mean=np variance=npq median=np

# %% [markdown]
# There is approximately a 15.87% probability that a randomly selected observation will be greater than 60.

# %% [markdown]
# A uniform distribution is a probability distribution in which all outcomes are equally likely within a given range.
# Tossing a dice.

# %% [markdown]
# Z score is difference between point and the mean divided by standard deviation.Standardization of data

# %% [markdown]
# The Central Limit Theorem states that the sampling distribution of the sample mean tends to be normally distributed as the sample size becomes large, regardless of the shape of the original population distribution, provided the observations are independent and identically distributed.
# Widely applicable
# Used in economics, engineering, medicine, and social sciences.

# %% [markdown]
# Random Sampling
# Independence of Observations
# Identically Distributed Variables
# Finite Mean and Variance

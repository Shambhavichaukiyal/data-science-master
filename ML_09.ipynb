# %% [markdown]
# Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an
# example of each.
# Simple linear regresssion is a regression technique in which we have one dependent feature and one independant feature.
# ex-house size and house price
#
# Multiple linear regression is a regression technique in which we have many dependent features and one independent features.
# ex-house size,no of rooms and houe price

# %% [markdown]
# Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in
# a given dataset?
#
# Linear dependent
# No Multicollinearity is allowed
#
# We can  check this by visualizing the dataset.
# For multicollinearity check by corr matrix

# %% [markdown]
# Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using
# a real-world scenario.
# So intercept can be calculated value of y when x=0.
# ex-
# salary=30000+5000 * experience

# %% [markdown]
# Q4. Explain the concept of gradient descent. How is it used in machine learning?
# Gradient descent can be explained the technique to optimize the model error.
# To optimize the error

# %% [markdown]
# Q5. Describe the multiple linear regression model. How does it differ from simple linear regression?
# Simple linear regresssion is a regression technique in which we have one dependent feature and one independant feature.
# ex-house size and house price
#
# Multiple linear regression is a regression technique in which we have many dependent features and one independent features.
# ex-house size,no of rooms and houe price

# %% [markdown]
# Q6. Explain the concept of multicollinearity in multiple linear regression. How can you detect and
# address this issue?
# Multicollinearity means 2 or more features are highly correlated to each other.
# WE can detect it by corr matrix.

# %% [markdown]
# Q7. Describe the polynomial regression model. How is it different from linear regression?
# Simple linear regresssion is a regression technique in which we have one dependent feature and one independant feature.
# ex-house size and house price
#
# Polynomial regression models non-linear relationships.
# Predict population growth over time.

# %% [markdown]
# Q8. What are the advantages and disadvantages of polynomial regression compared to linear
# regression? In what situations would you prefer to use polynomial regression?
#
# Advantages
#
# Captures non-linear relationships
#
# More flexible than linear regression
#
# Better fit for complex patterns
#
#
# Disadvantages
#
# Overfitting risk with high degree
#
# Harder to interpret
#
# Sensitive to outliers
#
#
# Use when:
#
# Data shows curved pattern
#
# Linear regression gives high error

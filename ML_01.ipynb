# %% [markdown]
# Q1: Explain the following with an example:F
# C) Artificial Intelligence
# <) Machine Learning,
# I) Deep Learning
# Q2: What is supervised learning? List some examples of supervised learning.
# Q3: What is unsupervised learning? List some examples of unsupervised learning.
# Q4: What is the difference between AI, ML, DL, and DS?
# Q5: What are the main differences between supervised, unsupervised, and semi-supervised learning?
# Q6: What is train, test and validation split? Explain the importance of each term.
# Q7: How can unsupervised learning be used in anomaly detection?
# Q8: List down some commonly used supervised learning algorithms and unsupervised learning
# algorithms.

# %% [markdown]
# Q1: Explain the following with an example:F
# C) Artificial IntelligencJ
# <) Machine Learning,
# I) Deep Learning
#
# Artificial Intelligence can be defined as a application that works without human interaction.Ex-Self driving cars
# Machine Learning can be defined as subset of AI in which we collect analyze discover pattern through statistics and develop prediction system.Ex-Recommendation System
# Deep Learning can be defined as subset of ML in which model mimic human behaviour.Ex-Neural Network chatgpt

# %% [markdown]
# Q2: What is supervised learning? List some examples of supervised learning.
# Supervised learning when a model is trained on labeled data.Classification and Regression ML Algorithm.
# ex-House pricing system,email detection

# %% [markdown]
# What is unsupervised learning? List some examples of unsupervised learning.
# UnSupervised learning when a model is trained on unlabeled data.Clutering  ML Algorithm.
# ex-Customer segmentation

# %% [markdown]
# Q4: What is the difference between AI, ML, DL, and DS?
# Artificial Intelligence can be defined as a application that works without human interaction.Ex-Self driving cars
# Machine Learning can be defined as subset of AI in which we collect analyze discover pattern through statistics and develop prediction system.Ex-Recommendation System
# Deep Learning can be defined as subset of ML in which model mimic human behaviour.Ex-Neural Network chatgpt
# Data Science is something that overlaps with all of them

# %% [markdown]
# Q5: What are the main differences between supervised, unsupervised, and semi-supervised learning?
# UnSupervised learning when a model is trained on unlabeled data.Clutering  ML Algorithm.
# ex-Customer segmentation
# Supervised learning when a model is trained on labeled data.Classification and Regression ML Algorithm.
# ex-House pricing system,email detection
# Semi-Supervised Learning-
# Supervised learning when a model is trained on labeled and unlabeled data.
# ex-Netflix recommendation based on location and preference

# %% [markdown]
#  What is train, test and validation split? Explain the importance of each term.
#  Dtaset is divided into 3 parts -
#  train dataset is used to train the model.
#  test dataset is used to test the model.
#  validation dataset is used to tune the hyperparameter.

# %% [markdown]
# Q7: How can unsupervised learning be used in anomaly detection?
# UnSupervised learning when a model is trained on unlabeled data.Clutering  ML Algorithm.
# ex-Customer segmentation
# Unsupervised learning discoveries the pattern in the dataset so the outlier can be easit detected in unsupervised learning

# %% [markdown]
# Q8: List down some commonly used supervised learning algorithms and unsupervised learning
# algorithms.
# Supervised-Linear Regression,Logistic Regression,
# Unsupervised-KNN clustering ,heirachial clustering
